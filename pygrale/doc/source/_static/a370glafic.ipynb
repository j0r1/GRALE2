# %%
# %matplotlib inline

# %%
from grale.all_nb import *
from astropy.io import fits
from astropy import wcs

renderers.setDefaultMassRenderer(None)
# Out:
# Set 'threads' as default renderer for lensplane and mass density
# Set default angular unit in plotting to arcsec
# Set feedback style to 'notebook'

# %%
cosm = cosmology.Cosmology(0.7, 0.3, 0, 0.7)
cosmology.setDefaultCosmology(cosm)
D = cosm.getAngularDiameterDistance

zd = 0.375

# %%
alphax = fits.open("hlsp_frontier_model_abell370_glafic_v4_x-arcsec-deflect.fits")[0]
alphay = fits.open("hlsp_frontier_model_abell370_glafic_v4_y-arcsec-deflect.fits")[0]

# %%
w = wcs.WCS(alphax.header)
numY, numX = alphax.data.shape

numY, numX
# Out:
# (6000, 5333)

# %%
ctrDeg = (np.array(w.all_pix2world(0, 0, 0)) + np.array(w.all_pix2world(numX, numY, 0)))/2

# %%
corner1 = np.array(w.all_pix2world(0, 0, 0))
corner1 = images.centerOnPosition(corner1*ANGLE_DEGREE, ctrDeg*ANGLE_DEGREE)
corner2 = np.array(w.all_pix2world(numX, numY, 0))
corner2 = images.centerOnPosition(corner2*ANGLE_DEGREE, ctrDeg*ANGLE_DEGREE)

corner1/ANGLE_ARCSEC, corner2/ANGLE_ARCSEC, (corner1-corner2)/ANGLE_ARCSEC
# Out:
# (array([ 79.99403623, -90.00041389]),
#  array([-79.99595519,  89.99956103]),
#  array([ 159.98999142, -179.99997492]))

# %%
angles = np.empty((numY,numX,2), dtype=np.double)
angles[:,:,0] = -alphax.data*ANGLE_ARCSEC
angles[:,:,1] = alphay.data*ANGLE_ARCSEC

# %%
model = lenses.DeflectionGridLens(D(zd), { 
    "angles": angles, 
    "bottomleft": corner1,
    "topright": corner2
})

sigmaCrit = model.getCriticalDensity(1,1)

# %%
li = plotutil.LensInfo(model, size=150*ANGLE_ARCSEC, zd=zd)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plotutil.plotDensity(li, densityUnit=sigmaCrit, vmax=5)
plt.gca().invert_xaxis()
plt.title("Kappa based on deflection angles")
plt.subplot(1,2,2)
plt.imshow(fits.open("hlsp_frontier_model_abell370_glafic_v4_kappa.fits")[0].data, extent=[80,-80,80,-80], vmax=5)
plt.gca().invert_yaxis()
plt.gca().set_xlim(left=75, right=-75)
plt.gca().set_ylim(top=75, bottom=-75)
plt.title("Kappa from fits file")
plt.show()
plotutil.plotDensityInteractive(li, densityUnit=sigmaCrit, flipX=True)
# Out:
# <iframe srcdoc='
# <html>
#     <head>
#         <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.21.0/vis.min.css" type="text/css" rel="stylesheet" />
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/vis/4.21.0/vis.min.js" type="text/javascript"></script>
#         <script src="https://cdn.rawgit.com/gliffy/canvas2svg/master/canvas2svg.js" type="text/javascript"></script>
#         <script src="https://cdn.rawgit.com/eligrey/FileSaver.js/b4a918669accb81f184c610d741a4a8e1306aa27/FileSaver.js" type="text/javascript"></script>
#     </head>
#     <body>
#         <div id="pos" style="top:0px;left:0px;position:absolute;"></div>
#         <div id="visualization"></div>
#         <script type="text/javascript">
#         var data = new vis.DataSet();
#         data.add([{"x": 75.0, "y": -75.0, "z": 0.29839771852935704}, {"x": 72.97297297297298, "y": -75.0, "z": 0.3047136273810819}, {"x": 70.94594594594595, "y": -75.0, "z": 0.3103788993322147}, {"x": 68.91891891891892, "y": -75.0, "z": 0.3157882424549824}, {"x": 66.89189189189189, "y": -75.0, "z": 0.3213230628481215}, {"x": 64.86486486486487, "y": -75.0, "z": 0.3274097772535227}, {"x": 62.83783783783784, "y": -75.0, "z": 0.3339964500113411}, {"x": 60.81081081081081, "y": -75.0, "z": 0.3410939752690431}, {"x": 58.78378378378378, "y": -75.0, "z": 0.3485876908507202}, {"x": 56.75675675675676, "y": -75.0, "z": 0.3565870089339167}, {"x": 54.72972972972973, "y": -75.0, "z": 0.36501656890214956}, {"x": 52.70270270270271, "y": -75.0, "z": 0.3736440108358549}, {"x": 50.675675675675684, "y": -75.0, "z": 0.38296898463945095}, {"x": 48.648648648648646, "y": -75.0, "z": 0.3920668865778681}, {"x": 46.62162162162162, "y": -75.0, "z": 0.40146921243964373}, {"x": 44.59459459459459, "y": -75.0, "z": 0.4114653521889077}, {"x": 42.567567567567565, "y": -75.0, "z": 0.4219349070539611}, {"x": 40.54054054054054, "y": -75.0, "z": 0.43307735916654694}, {"x": 38.513513513513516, "y": -75.0, "z": 0.44540026902682567}, {"x": 36.48648648648649, "y": -75.0, "z": 0.4580246375871288}, {"x": 34.45945945945946, "y": -75.0, "z": 0.4718395251761771}, {"x": 32.432432432432435, "y": -75.0, "z": 0.490191378073821}, {"x": 30.405405405405403, "y": -75.0, "z": 0.5379184425320377}, {"x": 28.37837837837838, "y": -75.0, "z": 0.9073226845194569}, {"x": 26.351351351351354, "y": -75.0, "z": 0.5967023493962832}, {"x": 24.32432432432433, "y": -75.0, "z": 0.5422223945717124}, {"x": 22.297297297297295, "y": -75.0, "z": 0.5443654759516477}, {"x": 20.27027027027027, "y": -75.0, "z": 0.5540538539975168}, {"x": 18.243243243243246, "y": -75.0, "z": 0.5652970388225281}, {"x": 16.216216216216218, "y": -75.0, "z": 0.5766568616611162}, {"x": 14.189189189189184, "y": -75.0, "z": 0.5877039635307015}, {"x": 12.16216216216216, "y": -75.0, "z": 0.5981353346823031}, {"x": 10.135135135135135, "y": -75.0, "z": 0.6076229045821695}, {"x": 8.108108108108109, "y": -75.0, "z": 0.6160333948844172}, {"x": 6.081081081081085, "y": -75.0, "z": 0.6232191449742159}, {"x": 4.054054054054049, "y": -75.0, "z": 0.6295110243123021}, {"x": 2.0270270270270245, "y": -75.0, "z": 0.6348641773042691}, {"x": -0.0, "y": -75.0, "z": 0.6379066123708392}, {"x": -2.0270270270270245, "y": -75.0, "z": 0.6369064950926284}, {"x": -4.054054054054061, "y": -75.0, "z": 0.6326897336852343}, {"x": -6.081081081081085, "y": -75.0, "z": 0.6274282527606547}, {"x": -8.108108108108109, "y": -75.0, "z": 0.6221681467531079}, {"x": -10.135135135135135, "y": -75.0, "z": 0.6171236724795672}, {"x": -12.16216216216216, "y": -75.0, "z": 0.6120149710083248}, {"x": -14.189189189189195, "y": -75.0, "z": 0.6069018363154345}, {"x": -16.216216216216218, "y": -75.0, "z": 0.6015426628876727}, {"x": -18.243243243243246, "y": -75.0, "z": 0.5960592035330505}, {"x": -20.27027027027027, "y": -75.0, "z": 0.5903204506425032}, {"x": -22.297297297297295, "y": -75.0, "z": 0.5844357794931291}, {"x": -24.32432432432433, "y": -75.0, "z": 0.5786304401469619}, {"x": -26.351351351351344, "y": -75.0, "z": 0.5726215339447367}, {"x": -28.37837837837839, "y": -75.0, "z": 0.5652022145530382}, {"x": -30.405405405405414, "y": -75.0, "z": 0.557906939605298}, {"x": -32.432432432432435, "y": -75.0, "z": 0.5506503227716608}, {"x": -34.45945945945946, "y": -75.0, "z": 0.5432639860037671}, {"x": -36.48648648648649, "y": -75.0, "z": 0.5359039463156122}, {"x": -38.513513513513516, "y": -75.0, "z": 0.5283899218205765}, {"x": -40.54054054054054, "y": -75.0, "z": 0.5208375990261096}, {"x": -42.567567567567565, "y": -75.0, "z": 0.5133112200361797}, {"x": -44.59459459459459, "y": -75.0, "z": 0.5057371374514064}, {"x": -46.621621621621635, "y": -75.0, "z": 0.4982505361321901}, {"x": -48.64864864864866, "y": -75.0, "z": 0.49091532375357677}, {"x": -50.675675675675684, "y": -75.0, "z": 0.48 ...
