# %%
# %matplotlib inline

# %%
from grale.all_nb import *
from astropy.io import fits
from astropy import wcs
# Out:
# Set 'threads' as default renderer for lensplane and mass density
# Set default angular unit in plotting to arcsec
# Set feedback style to 'notebook'

# %%
cosm = cosmology.Cosmology(0.7, 0.3, 0, 0.7)
cosmology.setDefaultCosmology(cosm)
D = cosm.getAngularDiameterDistance

zd = 0.375

# %%
alphax = fits.open("hlsp_frontier_model_abell370_diego_v4.1_x-arcsec-deflect.fits")[0]
alphay = fits.open("hlsp_frontier_model_abell370_diego_v4.1_y-arcsec-deflect.fits")[0]

# %%
w = wcs.WCS(alphax.header)
numY, numX = alphax.data.shape

numY, numX
# Out:
# (512, 512)

# %%
ctrDeg = (np.array(w.all_pix2world(0, 0, 0)) + np.array(w.all_pix2world(numX, numY, 0)))/2

# %%
corner1 = np.array(w.all_pix2world(0, 0, 0))
corner1 = images.centerOnPosition(corner1*ANGLE_DEGREE, ctrDeg*ANGLE_DEGREE)
corner2 = np.array(w.all_pix2world(numX, numY, 0))
corner2 = images.centerOnPosition(corner2*ANGLE_DEGREE, ctrDeg*ANGLE_DEGREE)

corner1/ANGLE_ARCSEC, corner2/ANGLE_ARCSEC, (corner1-corner2)/ANGLE_ARCSEC
# Out:
# (array([ 107.9984324 , -108.00075721]),
#  array([-108.00153572,  107.99920552]),
#  array([ 215.99996812, -215.99996273]))

# %%
angles = np.empty((numY,numX,2), dtype=np.double)
angles[:,:,0] = -alphax.data*ANGLE_ARCSEC
angles[:,:,1] = alphay.data*ANGLE_ARCSEC

# %%
model = lenses.DeflectionGridLens(D(zd), { 
    "angles": angles, 
    "bottomleft": corner1,
    "topright": corner2
})

sigmaCrit = model.getCriticalDensity(1,1)

# %%
li = plotutil.LensInfo(model, size=200*ANGLE_ARCSEC, zd=zd)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plotutil.plotDensity(li, densityUnit=sigmaCrit)
plt.gca().invert_xaxis()
plt.title("Kappa based on deflection angles")
plt.subplot(1,2,2)
plt.imshow(fits.open("hlsp_frontier_model_abell370_diego_v4.1_kappa.fits")[0].data, extent=[108,-108,108,-108])
plt.gca().invert_yaxis()
plt.gca().set_xlim(left=100, right=-100)
plt.gca().set_ylim(top=100, bottom=-100)
plt.title("Kappa from fits file")
plt.show()
plotutil.plotDensityInteractive(li, densityUnit=sigmaCrit, flipX=True)
# Out:
# Text(value='')
# FloatProgress(value=0.0)
# /home/jori/anaconda3-202002/envs/grale2env202002/lib/python3.8/site-packages/IPython/core/display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe srcdoc='
# <html>
#     <head>
#         <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.21.0/vis.min.css" type="text/css" rel="stylesheet" />
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/vis/4.21.0/vis.min.js" type="text/javascript"></script>
#         <script src="https://cdn.rawgit.com/gliffy/canvas2svg/master/canvas2svg.js" type="text/javascript"></script>
#         <script src="https://cdn.rawgit.com/eligrey/FileSaver.js/b4a918669accb81f184c610d741a4a8e1306aa27/FileSaver.js" type="text/javascript"></script>
#     </head>
#     <body>
#         <div id="pos" style="top:0px;left:0px;position:absolute;"></div>
#         <div id="visualization"></div>
#         <script type="text/javascript">
#         var data = new vis.DataSet();
#         data.add([{"x": 100.0, "y": -100.0, "z": 0.01012281158738753}, {"x": 97.29729729729729, "y": -100.0, "z": 0.011510095446252255}, {"x": 94.5945945945946, "y": -100.0, "z": 0.013000829418987886}, {"x": 91.89189189189189, "y": -100.0, "z": 0.014645614072141601}, {"x": 89.18918918918918, "y": -100.0, "z": 0.016507444004845058}, {"x": 86.48648648648648, "y": -100.0, "z": 0.01866306695896927}, {"x": 83.78378378378379, "y": -100.0, "z": 0.02118949018857486}, {"x": 81.08108108108108, "y": -100.0, "z": 0.024170742765064354}, {"x": 78.37837837837839, "y": -100.0, "z": 0.02769906818973873}, {"x": 75.67567567567566, "y": -100.0, "z": 0.03185956156527674}, {"x": 72.97297297297298, "y": -100.0, "z": 0.036749273902067676}, {"x": 70.27027027027026, "y": -100.0, "z": 0.04246636084306484}, {"x": 67.56756756756756, "y": -100.0, "z": 0.04909595842867099}, {"x": 64.86486486486487, "y": -100.0, "z": 0.0567219316766472}, {"x": 62.16216216216216, "y": -100.0, "z": 0.06543815059100301}, {"x": 59.45945945945946, "y": -100.0, "z": 0.07531209377545146}, {"x": 56.75675675675676, "y": -100.0, "z": 0.0864067632628837}, {"x": 54.054054054054056, "y": -100.0, "z": 0.09880359040124029}, {"x": 51.35135135135135, "y": -100.0, "z": 0.11255087664747802}, {"x": 48.648648648648646, "y": -100.0, "z": 0.12771332686504575}, {"x": 45.945945945945944, "y": -100.0, "z": 0.1443371342975143}, {"x": 43.24324324324324, "y": -100.0, "z": 0.16247827959620867}, {"x": 40.54054054054054, "y": -100.0, "z": 0.18217051545742777}, {"x": 37.83783783783783, "y": -100.0, "z": 0.2034991012447252}, {"x": 35.135135135135144, "y": -100.0, "z": 0.22655347215008864}, {"x": 32.432432432432435, "y": -100.0, "z": 0.25153420246366126}, {"x": 29.729729729729737, "y": -100.0, "z": 0.27875994658207504}, {"x": 27.02702702702703, "y": -100.0, "z": 0.3086742148206778}, {"x": 24.32432432432433, "y": -100.0, "z": 0.34179073591113446}, {"x": 21.621621621621625, "y": -100.0, "z": 0.3786357783641668}, {"x": 18.918918918918923, "y": -100.0, "z": 0.41950511525807277}, {"x": 16.216216216216218, "y": -100.0, "z": 0.4642977250568413}, {"x": 13.513513513513516, "y": -100.0, "z": 0.5122770428594605}, {"x": 10.810810810810812, "y": -100.0, "z": 0.5619753177273961}, {"x": 8.108108108108109, "y": -100.0, "z": 0.6111486941844919}, {"x": 5.405405405405406, "y": -100.0, "z": 0.6569709555137925}, {"x": 2.702702702702703, "y": -100.0, "z": 0.6963925037320688}, {"x": -0.0, "y": -100.0, "z": 0.7264237568633267}, {"x": -2.702702702702703, "y": -100.0, "z": 0.7447658968877662}, {"x": -5.4054054054053955, "y": -100.0, "z": 0.7499233116501655}, {"x": -8.108108108108109, "y": -100.0, "z": 0.7416966863631465}, {"x": -10.810810810810802, "y": -100.0, "z": 0.7209059638688113}, {"x": -13.513513513513516, "y": -100.0, "z": 0.6895251955900483}, {"x": -16.216216216216207, "y": -100.0, "z": 0.6501197331680849}, {"x": -18.918918918918923, "y": -100.0, "z": 0.6057129557781281}, {"x": -21.621621621621614, "y": -100.0, "z": 0.5592718988714497}, {"x": -24.32432432432433, "y": -100.0, "z": 0.5134164654234746}, {"x": -27.02702702702702, "y": -100.0, "z": 0.4702662031473537}, {"x": -29.729729729729712, "y": -100.0, "z": 0.4312477965392592}, {"x": -32.43243243243243, "y": -100.0, "z": 0.39717518643837896}, {"x": -35.13513513513512, "y": -100.0, "z": 0.3682300406474759}, {"x": -37.83783783783783, "y": -100.0, "z": 0.34416736097030826}, {"x": -40.540540540540526, "y": -100.0, "z": 0.32440416584756576}, {"x": -43.24324324324324, "y": -100.0, "z": 0.3082070711020433}, {"x": -45.94594594594593, "y": -100.0, "z": 0.2947852129600017}, {"x": -48.648648648648646, "y": -100.0, "z": 0.28339867051598827}, {"x": -51.35135135135134, "y": -100.0, "z": 0.27339194198757916}, {"x": -54.054054054054056, "y": -100.0, "z": 0.2642349849685579}, {"x": -56.756756756756744, "y": -100.0, "z": 0.25551202434378406}, {"x": -59.45945945945946, "y": -100.0, "z": 0.24692250542875027}, {"x": -62.162162162162154, "y": -100.0, "z": 0.2382405471920543}, {"x": -64.8648648648 ...
