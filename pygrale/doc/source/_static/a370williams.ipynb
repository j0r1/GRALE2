# %%
# %matplotlib inline

# %%
from grale.all_nb import *
from astropy.io import fits
from astropy import wcs

renderers.setDefaultMassRenderer(None)
# Out:
# Set 'threads' as default renderer for lensplane and mass density
# Set default angular unit in plotting to arcsec
# Set feedback style to 'notebook'

# %%
cosm = cosmology.Cosmology(0.7, 0.3, 0, 0.7)
cosmology.setDefaultCosmology(cosm)
D = cosm.getAngularDiameterDistance

zd = 0.375

# %%
alphax = fits.open("hlsp_frontier_model_abell370_williams_v4_x-arcsec-deflect.fits")[0]
alphay = fits.open("hlsp_frontier_model_abell370_williams_v4_y-arcsec-deflect.fits")[0]

# %%
w = wcs.WCS(alphax.header)
numY, numX = alphax.data.shape

numY, numX
# Out:
# (749, 749)

# %%
ctrDeg = (np.array(w.all_pix2world(0, 0, 0)) + np.array(w.all_pix2world(numX, numY, 0)))/2

# %%
corner1 = np.array(w.all_pix2world(0, 0, 0))
corner1 = images.centerOnPosition(corner1*ANGLE_DEGREE, ctrDeg*ANGLE_DEGREE)
corner2 = np.array(w.all_pix2world(numX, numY, 0))
corner2 = images.centerOnPosition(corner2*ANGLE_DEGREE, ctrDeg*ANGLE_DEGREE)

corner1/ANGLE_ARCSEC, corner2/ANGLE_ARCSEC, (corner1-corner2)/ANGLE_ARCSEC
# Out:
# (array([ 74.89939583, -74.90021717]),
#  array([-74.90089472,  74.8994677 ]),
#  array([ 149.80029055, -149.79968486]))

# %%
angles = np.empty((numY,numX,2), dtype=np.double)
angles[:,:,0] = -alphax.data*ANGLE_ARCSEC
angles[:,:,1] = alphay.data*ANGLE_ARCSEC

# %%
model = lenses.DeflectionGridLens(D(zd), { 
    "angles": angles, 
    "bottomleft": corner1,
    "topright": corner2
})

sigmaCrit = model.getCriticalDensity(1,1)

# %%
li = plotutil.LensInfo(model, size=148*ANGLE_ARCSEC, zd=zd)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plotutil.plotDensity(li, densityUnit=sigmaCrit)
plt.gca().invert_xaxis()
plt.title("Kappa based on deflection angles")
plt.subplot(1,2,2)
plt.imshow(fits.open("hlsp_frontier_model_abell370_williams_v4_kappa.fits")[0].data, extent=[74.9,-74.9,74.9,-74.9])
plt.gca().invert_yaxis()
plt.gca().set_xlim(left=74, right=-74)
plt.gca().set_ylim(top=74, bottom=-74)
plt.title("Kappa from fits file")
plt.show()
plotutil.plotDensityInteractive(li, densityUnit=sigmaCrit, flipX=True)
# Out:
# Text(value='')
# FloatProgress(value=0.0)
# /home/jori/anaconda3-202002/envs/grale2env202002/lib/python3.8/site-packages/IPython/core/display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe srcdoc='
# <html>
#     <head>
#         <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.21.0/vis.min.css" type="text/css" rel="stylesheet" />
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/vis/4.21.0/vis.min.js" type="text/javascript"></script>
#         <script src="https://cdn.rawgit.com/gliffy/canvas2svg/master/canvas2svg.js" type="text/javascript"></script>
#         <script src="https://cdn.rawgit.com/eligrey/FileSaver.js/b4a918669accb81f184c610d741a4a8e1306aa27/FileSaver.js" type="text/javascript"></script>
#     </head>
#     <body>
#         <div id="pos" style="top:0px;left:0px;position:absolute;"></div>
#         <div id="visualization"></div>
#         <script type="text/javascript">
#         var data = new vis.DataSet();
#         data.add([{"x": 74.0, "y": -74.0, "z": 0.10374061988657118}, {"x": 72.0, "y": -74.0, "z": 0.11802169981949984}, {"x": 70.0, "y": -74.0, "z": 0.13271936265620707}, {"x": 68.0, "y": -74.0, "z": 0.14756971784256634}, {"x": 66.0, "y": -74.0, "z": 0.16195477662406643}, {"x": 64.00000000000001, "y": -74.0, "z": 0.17494208824919016}, {"x": 62.0, "y": -74.0, "z": 0.18618822244237435}, {"x": 60.00000000000001, "y": -74.0, "z": 0.19417521350555014}, {"x": 58.00000000000001, "y": -74.0, "z": 0.19786697826620678}, {"x": 56.00000000000001, "y": -74.0, "z": 0.19961312891027932}, {"x": 54.00000000000001, "y": -74.0, "z": 0.20245952013362953}, {"x": 52.00000000000001, "y": -74.0, "z": 0.20687901136028022}, {"x": 50.00000000000001, "y": -74.0, "z": 0.20971382234866043}, {"x": 48.0, "y": -74.0, "z": 0.2103091728024277}, {"x": 46.00000000000001, "y": -74.0, "z": 0.21207150419128795}, {"x": 44.00000000000001, "y": -74.0, "z": 0.21934688635429206}, {"x": 42.00000000000001, "y": -74.0, "z": 0.23037893732850687}, {"x": 40.00000000000001, "y": -74.0, "z": 0.23902406834884263}, {"x": 38.0, "y": -74.0, "z": 0.24282996371460266}, {"x": 36.00000000000001, "y": -74.0, "z": 0.2445734033572333}, {"x": 34.00000000000001, "y": -74.0, "z": 0.24964174622864993}, {"x": 32.00000000000001, "y": -74.0, "z": 0.2556953643279423}, {"x": 30.000000000000004, "y": -74.0, "z": 0.25751892701062434}, {"x": 28.000000000000004, "y": -74.0, "z": 0.2586139012561214}, {"x": 26.000000000000004, "y": -74.0, "z": 0.2620697517616442}, {"x": 24.000000000000007, "y": -74.0, "z": 0.2676934284273339}, {"x": 22.0, "y": -74.0, "z": 0.2724699822515153}, {"x": 20.00000000000001, "y": -74.0, "z": 0.26957453416005983}, {"x": 18.00000000000001, "y": -74.0, "z": 0.2591275790735945}, {"x": 16.000000000000007, "y": -74.0, "z": 0.2486996774478666}, {"x": 14.000000000000007, "y": -74.0, "z": 0.24120760818995512}, {"x": 12.000000000000007, "y": -74.0, "z": 0.23509668892847485}, {"x": 10.000000000000005, "y": -74.0, "z": 0.2308228782023238}, {"x": 8.000000000000004, "y": -74.0, "z": 0.23119782207326672}, {"x": 6.0000000000000036, "y": -74.0, "z": 0.2377514116959971}, {"x": 4.000000000000002, "y": -74.0, "z": 0.2455205944089682}, {"x": 2.000000000000001, "y": -74.0, "z": 0.2425949971822638}, {"x": -0.0, "y": -74.0, "z": 0.2274921421670966}, {"x": -1.9999999999999898, "y": -74.0, "z": 0.2133545345817739}, {"x": -3.999999999999991, "y": -74.0, "z": 0.2030736875607643}, {"x": -5.999999999999992, "y": -74.0, "z": 0.19057282963225747}, {"x": -7.999999999999993, "y": -74.0, "z": 0.17789982433345677}, {"x": -9.999999999999995, "y": -74.0, "z": 0.17177762024735121}, {"x": -11.999999999999995, "y": -74.0, "z": 0.17322552638595526}, {"x": -13.999999999999996, "y": -74.0, "z": 0.17867496858945023}, {"x": -15.999999999999996, "y": -74.0, "z": 0.18171141513080274}, {"x": -18.0, "y": -74.0, "z": 0.1813292469153688}, {"x": -20.0, "y": -74.0, "z": 0.18286296555126588}, {"x": -22.0, "y": -74.0, "z": 0.185778901803295}, {"x": -23.99999999999999, "y": -74.0, "z": 0.1898752630307334}, {"x": -25.999999999999993, "y": -74.0, "z": 0.19738614619525416}, {"x": -27.999999999999993, "y": -74.0, "z": 0.20376525957361297}, {"x": -30.000000000000004, "y": -74.0, "z": 0.206389977397843}, {"x": -31.999999999999993, "y": -74.0, "z": 0.20981685232106978}, {"x": -33.999999999999986, "y": -74.0, "z": 0.21422521400064726}, {"x": -36.0, "y": -74.0, "z": 0.21519574725670626}, {"x": -37.999999999999986, "y": -74.0, "z": 0.2140706092014531}, {"x": -40.0, "y": -74.0, "z": 0.21404004512621785}, {"x": -41.999999999999986, "y": -74.0, "z": 0.21464647285574387}, {"x": -44.0, "y": -74.0, "z": 0.21424559227226914}, {"x": -45.99999999999999, "y": -74.0, "z": 0.20735057770743123}, {"x": -48.0, "y": -74.0, "z": 0.19443912666227414}, {"x": -49.99999999999999, "y": -74.0, "z": 0.1820115846416217}, {"x": -52.00000000000001, "y": -74.0, "z": 0.17088887062696514}, {"x": -53.99999999999999, "y": -74.0, "z": 0.1592556542229231}, {"x": -55.99999999999 ...
