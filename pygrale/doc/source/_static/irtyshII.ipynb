# %% [markdown]
# This notebook shows how the model for IrtyshII, see [Free-form grale lens inversion of galaxy clusters with up to 1000 multiple images](https://ui.adsabs.harvard.edu/abs/2020MNRAS.494.3998G/abstract), can be imported as a Grale model. The
# cluster itself was modeled using [gravlens/lensmodel](https://www.physics.rutgers.edu/~keeton/gravlens/2012WS/), see also [Keeton 2001](https://ui.adsabs.harvard.edu/abs/2001astro.ph..2341K/abstract)

# %%
# %matplotlib inline

# %%
from grale.all_nb import *

cosm = cosmology.Cosmology(0.7, 0.3, 0, 0.7)
cosmology.setDefaultCosmology(cosm)

z_lens = 0.4

D = cosm.getAngularDiameterDistance
Dd = D(z_lens)
# Out:
# Set 'threads' as default renderer for lensplane and mass density
# Set default angular unit in plotting to arcsec
# Set feedback style to 'notebook'

# %%
def la(l):
    srcAndImg, xArcsec, yArcsec, z = l.split()
    xArcsec, yArcsec, z = map(float, [xArcsec, yArcsec, z])
    src, img = map(int, srcAndImg.split('.'))
    
    return { "x": xArcsec*ANGLE_ARCSEC, "y": yArcsec*ANGLE_ARCSEC, "srcnr": src, "imgnr": img, "z": z}
inputImages = images.readInputImagesFile('images_combined_IrtyshII.dat', isPointImagesFile=True, lineAnalyzer=la)

# %%
sources = [ ]
for line in open("sources_IrtyshII.dat", "rt"):
    line = line.strip()
    if not line:
        continue
    srcnum, xpos, ypos, z, mult = list(map(float, line.split()))
    sources.append({"srcnr": int(srcnum), "x": xpos*ANGLE_ARCSEC, "y": ypos*ANGLE_ARCSEC, "z": z})

# %%
alpha = 0.6

bScale = ANGLE_ARCSEC**(alpha-2)
lens1 = lenses.AlphaPotLens(Dd, { 
    "b": 22.4834/bScale,
    "alpha": alpha,
    "q": 1.0,
    "K2": -0.25,
    "s": 3.0*ANGLE_ARCSEC
})
lens2 = lenses.AlphaPotLens(Dd, { 
    "b": 22.4834/bScale,
    "alpha": alpha,
    "q": 1.0,
    "K2": 0.35,
    "s": 3.0*ANGLE_ARCSEC
})
lensesAndPositions = [ (lens1, V(13.35,-2.85)*ANGLE_ARCSEC), (lens2, V(-9.45,12.75)*ANGLE_ARCSEC) ]

alpha = 0.45
bScale = ANGLE_ARCSEC**(alpha-2)
for line in open("small_lenses_IrtyshII.dat", "rt"):
    nr, xpos, ypos, b = map(float, line.split())
    lens = lenses.AlphaPotLens(Dd, {
        "b": b/bScale,
        "alpha": alpha,
        "q": 1.0,
        "K2": 0,
        "s": 3.0*ANGLE_ARCSEC
    })
    lensesAndPositions.append((lens, V(xpos, ypos)*ANGLE_ARCSEC))

# %%
compositeLensParams = [ { "x": p[0], "y": p[1], "factor":1, "angle": 0, "lens": l} for l, p in lensesAndPositions ]
compLens = lenses.CompositeLens(Dd, compositeLensParams)

# %%
li = plotutil.LensInfo(compLens, size=95*ANGLE_ARCSEC, center=[0,5*ANGLE_ARCSEC], Ds=1, Dds=0.8)

# %%
sigmaCrit = compLens.getCriticalDensity(1,1)

plotutil.plotDensityInteractive(li, densityUnit=sigmaCrit)
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
x": -8.986486486486488, "y": -42.5, "z": 0.3460100781996408}, {"x": -7.7027027027027, "y": -42.5, "z": 0.31144154388197826}, {"x": -6.418918918918918, "y": -42.5, "z": 0.2856568621071557}, {"x": -5.135135135135137, "y": -42.5, "z": 0.26881225431805816}, {"x": -3.85135135135135, "y": -42.5, "z": 0.2580842247613133}, {"x": -2.5675675675675684, "y": -42.5, "z": 0.2511659606233038}, {"x": -1.2837837837837816, "y": -42.5, "z": 0.24660182108429915}, {"x": 0.0, "y": -42.5, "z": 0.24352257157924231}, {"x": 1.2837837837837816, "y": -42.5, "z": 0.24140553549963778}, {"x": 2.5675675675675684, "y": -42.5, "z": 0.23992767696054507}, {"x": 3.85135135135135, "y": -42.5, "z": 0.2388829536133546}, {"x": 5.1351351351351315, "y": -42.5, "z": 0.23813629384810672}, {"x": 6.418918918918925, "y": -42.5, "z": 0.23759760583236156}, {"x": 7.702702702702706, "y": -42.5, "z": 0.23720699500970058}, {"x": 8.986486486486488, "y": -42.5, "z": 0.23692567198405384}, {"x": 10.270270270270268, "y": -42.5, "z": 0.23673161522511743}, {"x": 11.55405405405405, "y": -42.5, "z": 0.23661706338107627}, {"x": 12.837837837837844, "y": -42.5, "z": 0.23658758809791666}, {"x": 14.121621621621625, "y": -42.5, "z": 0.23666209401033694}, {"x": 15.405405405405405, "y": -42.5, "z": 0.23687278999399328}, {"x": 16.689189189189186, "y": -42.5, "z": 0.23726376365707627}, {"x": 17.97297297297297, "y": -42.5, "z": 0.2378858904446573}, {"x": 19.25675675675676, "y": -42.5, "z": 0.23878446869302444}, {"x": 20.540540540540544, "y": -42.5, "z": 0.23997462438829253}, {"x": 21.824324324324326, "y": -42.5, "z": 0.24139927875406653}, {"x": 23.108108108108105, "y": -42.5, "z": 0.24287011380649756}, {"x": 24.391891891891888, "y": -42.5, "z": 0.24401580517852278}, {"x": 25.67567567567568, "y": -42.5, "z": 0.24428373730760297}, {"x": 26.959459459459463, "y": -42.5, "z": 0.24306078773322043}, {"x": 28.243243243243242, "y": -42.5, "z": 0.23991192096736716}, {"x": 29.527027027027025, "y": -42.5, "z": 0.23480317457371408}, {"x": 30.810810810810807, "y": -42.5, "z": 0.2281292195 ...
# Text(value='')
# FloatProgress(value=0.0)

# %%
iws = inversion.InversionWorkSpace(zLens=0.4, regionSize=20*ANGLE_ARCSEC, 
                                   regionCenter=[2.5*ANGLE_ARCSEC, 2.5*ANGLE_ARCSEC])

for img in inputImages:
    iws.addImageDataToList(img['imgdata'], img['z'], 'pointimages')

# %%
bpImages = iws.backProject(compLens)
plt.figure(figsize=(8,8))
plotutil.plotImagesData(bpImages)

sourceX = np.array([ s["x"] for s in sources])
sourceY = np.array([ s["y"] for s in sources])
plt.plot(sourceX/ANGLE_ARCSEC, sourceY/ANGLE_ARCSEC, "x")
plt.gca().set_aspect("equal")
plt.show()
