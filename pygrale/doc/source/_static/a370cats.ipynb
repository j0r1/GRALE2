# %%
# %matplotlib inline

# %%
from grale.all_nb import *
from astropy.io import fits
from astropy import wcs

renderers.setDefaultMassRenderer(None)
# Out:
# Set 'threads' as default renderer for lensplane and mass density
# Set default angular unit in plotting to arcsec
# Set feedback style to 'notebook'

# %%
cosm = cosmology.Cosmology(0.7, 0.3, 0, 0.7)
cosmology.setDefaultCosmology(cosm)
D = cosm.getAngularDiameterDistance

zd = 0.375

# %%
alphax = fits.open("hlsp_frontier_model_abell370_cats_v4_x-arcsec-deflect.fits")[0]
alphay = fits.open("hlsp_frontier_model_abell370_cats_v4_y-arcsec-deflect.fits")[0]

# %%
w = wcs.WCS(alphax.header)
numY, numX = alphax.data.shape

numY, numX
# Out:
# (3000, 3000)

# %%
ctrDeg = (np.array(w.all_pix2world(0, 0, 0)) + np.array(w.all_pix2world(numX, numY, 0)))/2

# %%
corner1 = np.array(w.all_pix2world(0, 0, 0))
corner1 = images.centerOnPosition(corner1*ANGLE_DEGREE, ctrDeg*ANGLE_DEGREE)
corner2 = np.array(w.all_pix2world(numX, numY, 0))
corner2 = images.centerOnPosition(corner2*ANGLE_DEGREE, ctrDeg*ANGLE_DEGREE)

corner1/ANGLE_ARCSEC, corner2/ANGLE_ARCSEC, (corner1-corner2)/ANGLE_ARCSEC
# Out:
# (array([ 300.08775762, -300.10553773]),
#  array([-300.1118785 ,  300.09347727]),
#  array([ 600.19963611, -600.199015  ]))

# %%
angles = np.empty((numY,numX,2), dtype=np.double)
angles[:,:,0] = -alphax.data*ANGLE_ARCSEC
angles[:,:,1] = alphay.data*ANGLE_ARCSEC

# %%
model = lenses.DeflectionGridLens(D(zd), { 
    "angles": angles, 
    "bottomleft": corner1,
    "topright": corner2
})

sigmaCrit = model.getCriticalDensity(1,1)

# %%
li = plotutil.LensInfo(model, size=200*ANGLE_ARCSEC, zd=zd)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plotutil.plotDensity(li, densityUnit=sigmaCrit, vmax=5)
plt.gca().invert_xaxis()
plt.title("Kappa based on deflection angles")
plt.subplot(1,2,2)
plt.imshow(fits.open("hlsp_frontier_model_abell370_cats_v4_kappa.fits")[0].data, extent=[300,-300,300,-300], vmax=5)
plt.gca().set_xlim(left=100, right=-100)
plt.gca().set_ylim(top=100, bottom=-100)
plt.title("Kappa from fits file")
plt.show()
plotutil.plotDensityInteractive(li, densityUnit=sigmaCrit, flipX=True)
# Out:
# Text(value='')
# FloatProgress(value=0.0)
# /home/jori/anaconda3-202002/envs/grale2env202002/lib/python3.8/site-packages/IPython/core/display.py:717: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe srcdoc='
# <html>
#     <head>
#         <link href="https://cdnjs.cloudflare.com/ajax/libs/vis/4.21.0/vis.min.css" type="text/css" rel="stylesheet" />
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/vis/4.21.0/vis.min.js" type="text/javascript"></script>
#         <script src="https://cdn.rawgit.com/gliffy/canvas2svg/master/canvas2svg.js" type="text/javascript"></script>
#         <script src="https://cdn.rawgit.com/eligrey/FileSaver.js/b4a918669accb81f184c610d741a4a8e1306aa27/FileSaver.js" type="text/javascript"></script>
#     </head>
#     <body>
#         <div id="pos" style="top:0px;left:0px;position:absolute;"></div>
#         <div id="visualization"></div>
#         <script type="text/javascript">
#         var data = new vis.DataSet();
#         data.add([{"x": 100.0, "y": -100.0, "z": 0.07612948779130296}, {"x": 97.29729729729729, "y": -100.0, "z": 0.07996285291343622}, {"x": 94.5945945945946, "y": -100.0, "z": 0.08400359642942008}, {"x": 91.89189189189189, "y": -100.0, "z": 0.08825215563581466}, {"x": 89.18918918918918, "y": -100.0, "z": 0.09270024375493754}, {"x": 86.48648648648648, "y": -100.0, "z": 0.09737441247414164}, {"x": 83.78378378378379, "y": -100.0, "z": 0.10225998701659236}, {"x": 81.08108108108108, "y": -100.0, "z": 0.10735214411675575}, {"x": 78.37837837837839, "y": -100.0, "z": 0.11265355919015144}, {"x": 75.67567567567566, "y": -100.0, "z": 0.11814924172113854}, {"x": 72.97297297297298, "y": -100.0, "z": 0.12382639269696068}, {"x": 70.27027027027026, "y": -100.0, "z": 0.12965445819902904}, {"x": 67.56756756756756, "y": -100.0, "z": 0.1356244772802896}, {"x": 64.86486486486487, "y": -100.0, "z": 0.14168243315262113}, {"x": 62.16216216216216, "y": -100.0, "z": 0.14778979139867326}, {"x": 59.45945945945946, "y": -100.0, "z": 0.153915555087882}, {"x": 56.75675675675676, "y": -100.0, "z": 0.15998165677965076}, {"x": 54.054054054054056, "y": -100.0, "z": 0.16594392477464556}, {"x": 51.35135135135135, "y": -100.0, "z": 0.1717186663121986}, {"x": 48.648648648648646, "y": -100.0, "z": 0.17724990649996056}, {"x": 45.945945945945944, "y": -100.0, "z": 0.18246253489206582}, {"x": 43.24324324324324, "y": -100.0, "z": 0.18728406570781714}, {"x": 40.54054054054054, "y": -100.0, "z": 0.19166410074784399}, {"x": 37.83783783783783, "y": -100.0, "z": 0.1955415956122065}, {"x": 35.135135135135144, "y": -100.0, "z": 0.19887861418059408}, {"x": 32.432432432432435, "y": -100.0, "z": 0.2016653949858658}, {"x": 29.729729729729737, "y": -100.0, "z": 0.20389987805179877}, {"x": 27.02702702702703, "y": -100.0, "z": 0.20558204104335884}, {"x": 24.32432432432433, "y": -100.0, "z": 0.2067601133446005}, {"x": 21.621621621621625, "y": -100.0, "z": 0.2074817213028816}, {"x": 18.918918918918923, "y": -100.0, "z": 0.2078066861672516}, {"x": 16.216216216216218, "y": -100.0, "z": 0.20780685266090035}, {"x": 13.513513513513516, "y": -100.0, "z": 0.20756757585048302}, {"x": 10.810810810810812, "y": -100.0, "z": 0.2071610487708198}, {"x": 8.108108108108109, "y": -100.0, "z": 0.20667409650336213}, {"x": 5.405405405405406, "y": -100.0, "z": 0.2061913907731643}, {"x": 2.702702702702703, "y": -100.0, "z": 0.2057655848474937}, {"x": -0.0, "y": -100.0, "z": 0.2054719682423936}, {"x": -2.702702702702703, "y": -100.0, "z": 0.20535695856721434}, {"x": -5.4054054054053955, "y": -100.0, "z": 0.20547813669830806}, {"x": -8.108108108108109, "y": -100.0, "z": 0.20586065767716438}, {"x": -10.810810810810802, "y": -100.0, "z": 0.2065329755811173}, {"x": -13.513513513513516, "y": -100.0, "z": 0.20750560328902504}, {"x": -16.216216216216207, "y": -100.0, "z": 0.20877765692983286}, {"x": -18.918918918918923, "y": -100.0, "z": 0.21034258363622263}, {"x": -21.621621621621614, "y": -100.0, "z": 0.212186287425549}, {"x": -24.32432432432433, "y": -100.0, "z": 0.2142669461306939}, {"x": -27.02702702702702, "y": -100.0, "z": 0.2165492195222176}, {"x": -29.729729729729712, "y": -100.0, "z": 0.21896672223778654}, {"x": -32.43243243243243, "y": -100.0, "z": 0.22145821983674552}, {"x": -35.13513513513512, "y": -100.0, "z": 0.22394186244945624}, {"x": -37.83783783783783, "y": -100.0, "z": 0.2263395991064839}, {"x": -40.540540540540526, "y": -100.0, "z": 0.22853272408867972}, {"x": -43.24324324324324, "y": -100.0, "z": 0.23044168811756688}, {"x": -45.94594594594593, "y": -100.0, "z": 0.23196872416079498}, {"x": -48.648648648648646, "y": -100.0, "z": 0.2330136483938805}, {"x": -51.35135135135134, "y": -100.0, "z": 0.23348071655743738}, {"x": -54.054054054054056, "y": -100.0, "z": 0.23330605449176628}, {"x": -56.756756756756744, "y": -100.0, "z": 0.23243068727333738}, {"x": -59.45945945945946, "y": -100.0, "z": 0.2308259193245324}, {"x": -62.162162162162154, "y": -100.0, "z": 0.22846682335162546}, {"x": -64.86486486 ...
